# %%
#40
import random
import math
import turtle

def showMontePi(numDarts):
  wn = turtle.Screen()
  drawingT = turtle.Turtle()

  wn.setworldcoordinates(0,0,1,1)
  drawingT.up()
  drawingT.goto(0,0)
  drawingT.down()
  drawingT.goto(1,0)
  drawingT.up()
  drawingT.goto(0,0)
  drawingT.down()
  drawingT.goto(0,1)
  
  inCircle = 0
  drawingT.up()
  for i in range(numDarts):
    x=random.random()
    y=random.random()
    distance = math.sqrt(x**2+y**2)
    drawingT.goto(x,y)
    if distance<=1:
      inCircle = inCircle+1
      drawingT.color("blue")
    else:
      drawingT.color("red")
    drawingT.dot()
  pi = inCircle / numDarts*4
  wn.exitonclick()
  return pi

showMontePi(10000)
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[1], line 37
#      34   wn.exitonclick()
#      35   return pi
# ---> 37 showMontePi(10000)
#
# Cell In[1], line 26, in showMontePi(numDarts)
#      24 y=random.random()
#      25 distance = math.sqrt(x**2+y**2)
# ---> 26 drawingT.goto(x,y)
#      27 if distance<=1:
#      28   inCircle = inCircle+1
#
# File D:\mdrive\dacon\Anaconda3\envs\comp\lib\turtle.py:1776, in TNavigator.goto(self, x, y)
#    1774     self._goto(Vec2D(*x))
#    1775 else:
# -> 1776     self._goto(Vec2D(x, y))
#
# File D:\mdrive\dacon\Anaconda3\envs\comp\lib\turtle.py:3180, in RawTurtle._goto(self, end)
#    3176     if self._drawing:
#    3177         screen._drawline(self.drawingLineItem,
#    3178                          (start, self._position),
#    3179                          self._pencolor, self._pensize, top)
# -> 3180     self._update()
#    3181 if self._drawing:
#    3182     screen._drawline(self.drawingLineItem, ((0, 0), (0, 0)),
#    3183                                    fill="", width=self._pensize)
#
# File D:\mdrive\dacon\Anaconda3\envs\comp\lib\turtle.py:2660, in RawTurtle._update(self)
#    2658     return
#    2659 elif screen._tracing == 1:
# -> 2660     self._update_data()
#    2661     self._drawturtle()
#    2662     screen._update()                  # TurtleScreenBase
#
# File D:\mdrive\dacon\Anaconda3\envs\comp\lib\turtle.py:2646, in RawTurtle._update_data(self)
#    2645 def _update_data(self):
# -> 2646     self.screen._incrementudc()
#    2647     if self.screen._updatecounter != 0:
#    2648         return
#
# File D:\mdrive\dacon\Anaconda3\envs\comp\lib\turtle.py:1292, in TurtleScreen._incrementudc(self)
#    1290 if not TurtleScreen._RUNNING:
#    1291     TurtleScreen._RUNNING = True
# -> 1292     raise Terminator
#    1293 if self._tracing > 0:
#    1294     self._updatecounter += 1
#
# Terminator:

# %%
#41
import turtle
import random
import math

def showMontePi(numDarts):
  wn = turtle.Screen()
  drawingT = turtle.Turtle()

  wn.setworldcoordinates(-2,-2,2,2)
  drawingT.up()
  drawingT.goto(-1,0)
  drawingT.down()
  drawingT.goto(1,0)
  
  drawingT.up()
  drawingT.goto(0,1)
  drawingT.down()
  drawingT.goto(0,-1)
  
  inCircle = 0
  drawingT.up()
  for i in range(numDarts):
    x = random.uniform(-1,1)
    y = random.uniform(-1,1)
    distance = math.sqrt(x**2+y**2)
    drawingT.goto(x,y)
    
    if distance<=1:
      inCircle = inCircle+1
      drawingT.color("blue")
    else:
      drawingT.color("red")
    
    drawingT.dot()
    
  pi = inCircle / numDarts*4
  wn.exitonclick()
  return pi

showMontePi(10000)
#colab에서는 작동 안하므로, jupyter에서 실행해야함
